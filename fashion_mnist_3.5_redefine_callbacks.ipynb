# %% [markdown]
# # Fashion MNIST classification (cont.)

# %% [markdown]
# This notebook is built upon the [TensorFlow image classification tutorial](https://www.tensorflow.org/tutorials/keras/classification), which trains a neural network model to classify Fashion MNIST dataset. It's okay if you don't understand all the details of the implementation; this is a fast-paced overview of a complete TensorFlow program with the details explained as you go. We use [tf.keras](https://www.tensorflow.org/guide/keras), a high-level API to build and train models in TensorFlow.

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# set random seeds
np.random.seed(42)
tf.random.set_seed(42)
tf.compat.v1.set_random_seed(42)
tf.experimental.numpy.random.seed(42)
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# ## Preprocess the data as in the starter code

# %% [markdown]
# ### Import the Fashion MNIST dataset

# %% [markdown]
# You can access the Fashion MNIST directly from TensorFlow. Import and load the Fashion MNIST data directly from TensorFlow.

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# * The `train_images` and `train_labels` arrays are the *training set*—the data the model uses to learn.
# * The model is tested against the *test set*, the `test_images`, and `test_labels` arrays.
#
# We will split a validation set from the training set later.

# %% [markdown]
# ### Scale and flatten the images

# %% [markdown]
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. Scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, divide the values by 255. Moreover, flatten the 28x28 NumPy arrays into 784 dimension feature vectors.
#
# It's important that the *training set* and the *testing set* be preprocessed in the same way.

# %%
train_images = (train_images / 255.0).reshape(train_images.shape[0], -1)
test_images = (test_images / 255.0).reshape(test_images.shape[0], -1)
train_images.shape
# Out:
# (60000, 784)

# %% [markdown]
# The *labels* are an array of integers, ranging from 0 to 9. Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Split train/validation/test sets

# %% [markdown]
# Same as the starter code, take the first 10k data in the *training set* as the training data, and the last 2k data in the *training set* as the validation data. The test data is all the 10k data in the *testing set*.

# %%
# sample 5k training, 1k validation, making sure the label is balanced
label_idxs = [np.where(train_labels == i)[0] for i in range(10)]
Xtrain, Ytrain, Xval, Yval = \
    np.concatenate([train_images[label_idxs[i][:1000]] for i in range(10)]), \
    np.concatenate([train_labels[label_idxs[i][:1000]] for i in range(10)]), \
    np.concatenate([train_images[label_idxs[i][-200:]] for i in range(10)]), \
    np.concatenate([train_labels[label_idxs[i][-200:]] for i in range(10)])

# shuffle data before training
idx_order = np.random.permutation(Xtrain.shape[0])
Xtrain = Xtrain[idx_order]
Ytrain = Ytrain[idx_order]

Xtest, Ytest = test_images, test_labels

# %% [markdown]
# To verify that the data is in the correct format and that you're ready to build and train the network, let's display the first 25 images from the training data and display the class name below each image.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(Xtrain[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(class_names[Ytrain[i]])
plt.show()

# %% [markdown]
# ## Build the model
#
# Building the neural network requires configuring the layers of the model, then compiling the model.

# %% [markdown]
# ### Set up two linear layers
#
# The basic building block of a neural network is the [*layer*](https://www.tensorflow.org/api_docs/python/tf/keras/layers). Layers extract representations from the data fed into them. Hopefully, these representations are meaningful for the problem at hand.
#
# Most of deep learning consists of chaining together simple layers. Most layers, such as `tf.keras.layers.Dense`, have parameters that are learned during training.

# %%
base_model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# The network consists of a sequence of two `tf.keras.layers.Dense` layers. These are densely connected, or fully connected, neural layers. The first `Dense` layer has 1000 nodes (or neurons). The second layer returns a logits array with length of 10. Each node contains a score that indicates the current image belongs to one of the 10 classes.
#
# ### Compile the model
#
# Before the model is ready for training, it needs a few more settings. These are added during the model's [*compile*](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile) step:
#
# * [*Loss function*](https://www.tensorflow.org/api_docs/python/tf/keras/losses) —This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.
# * [*Optimizer*](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) —This is how the model is updated based on the data it sees and its loss function.
# * [*Metrics*](https://www.tensorflow.org/api_docs/python/tf/keras/metrics) —Used to monitor the training and testing steps. The following example uses *accuracy*, the fraction of the images that are correctly classified.

# %%
base_model.compile(optimizer='sgd',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Setup early-stopping
#
# Define the early-stopping module as a callback module to stop the training process.

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_accuracy",
        # "no longer improving" being defined as "for at least 3 epochs"
        patience=3,
        verbose=1,
    )
]

# %% [markdown]
# ## Train the model
#
# Training the neural network model requires the following steps:
#
# 1. Feed the training data to the model. In this example, the training data is in the `Xtrain` and `Ytrain` arrays.
# 2. The model learns to associate images and labels.
# 3. You ask the model to make predictions about a test set—in this example, the `Xtest` array.
# 4. Verify that the predictions match the labels from the `Ytest` array.

# %% [markdown]
# ### Feed the model

# %% [markdown]
# To start training,  call the [`model.fit`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) method—so called because it "fits" the model to the training data. It automatically processes the forward pass and the backward pass.
#
# ---

# %%
base_model.fit(
    Xtrain, Ytrain,
    batch_size=5, epochs=50,
    callbacks=callbacks,
    validation_data=(Xval, Yval))
# Out:
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7333 - loss: 0.7916 - val_accuracy: 0.7895 - val_loss: 0.5761
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8141 - loss: 0.5467 - val_accuracy: 0.8135 - val_loss: 0.5132
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8299 - loss: 0.4887 - val_accuracy: 0.8235 - val_loss: 0.4890
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8424 - loss: 0.4536 - val_accuracy: 0.8290 - val_loss: 0.4735
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8518 - loss: 0.4274 - val_accuracy: 0.8355 - val_loss: 0.4623
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8597 - loss: 0.4066 - val_accuracy: 0.8410 - val_loss: 0.4533
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8650 - loss: 0.3891 - val_accuracy: 0.8445 - val_loss: 0.4460
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8704 - loss: 0.3733 - val_accuracy: 0.8455 - val_loss: 0.4414
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8752 - loss: 0.3596 - val_accuracy: 0.8470 - val_loss: 0.4351
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8803 - loss: 0.3470 - val_accuracy: 0.8490 - val_loss: 0.4320
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8838 - loss: 0.3355 - val_accuracy: 0.8525 - val_loss: 0.4275
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8870 - loss: 0.3245 - val_accuracy: 0.8510 - val_loss: 0.4257
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8915 - loss: 0.3144 - val_accuracy: 0.8535 - val_loss: 0.4232
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8961 - loss: 0.3045 - val_accuracy: 0.8525 - val_loss: 0.4205
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8984 - loss: 0.2953 - val_accuracy: 0.8560 - val_loss: 0.4179
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9014 - loss: 0.2861 - val_accuracy: 0.8585 - val_loss: 0.4175
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9053 - loss: 0.2772 - val_accuracy: 0.8570 - val_loss: 0.4194
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9094 - loss: 0.2689 - val_accuracy: 0.8590 - val_loss: 0.4204
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9126 - loss: 0.2609 - val_accuracy: 0.8600 - val_loss: 0.4224
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9143 - loss: 0.2532 - val_accuracy: 0.8585 - val_loss: 0.4232
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9179 - loss: 0.2454 - val_accuracy: 0.8605 - val_loss: 0.4249
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9201 - loss: 0.2386 - val_accuracy: 0.8580 - val_loss: 0.4273
# Epoch 23/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9233 - loss: 0.2313 - val_accuracy: 0.8590 - val_loss: 0.4292
# Epoch 24/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9254 - loss: 0.2243 - val_accuracy: 0.8575 - val_loss: 0.4289
# Epoch 24: early stopping

# %% [markdown]
# ### Evaluate accuracy
#
# Next, compare how the model performs on the test dataset:

# %%
test_loss, test_acc = base_model.evaluate(Xtest,  Ytest, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8459 - loss: 0.4705
#
# Test accuracy: 0.8458999991416931

# %% [markdown]
# **The accuracy that we obtain here is similar (+/- 1.5) to the accuracy from your own Python code for a batch size of 5. You can check your results to verify this.**

# %% [markdown]
# ## Problem 3.3: The effect of early-stopping
#
# We provided built-in early-stopping in the starter code, but did not explore the effect that it has on training. In this question, we will explore the effect of early-stopping. To do this, we evaluate the training, validation and test accuracy for each training epoch. We then plot the training, validation and test accuracy throughout the training process to see how early-stopping works.
#
# To make sure the training process is the same as the previous `base_model`, we set the same random seed for training. Connecting all the training-evaluation modules together, we train 30 epochs on a batch size of 5 without early-stopping:

# %%
# set the same random seed to make sure the model initialized at the same weights.
tf.random.set_seed(42)
tf.compat.v1.set_random_seed(42)
tf.experimental.numpy.random.seed(42)
# build the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])
test_acc = []
# setup a callback for evaluate the test set
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        res_test = self.model.evaluate(Xtest, Ytest, verbose = 0)
        test_acc.append(res_test[1])
my_test_callback = TestCallback()
# compile the model
model.compile(optimizer='sgd',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# train the model without callbacks
train_test_history = model.fit(
    Xtrain, Ytrain,
    batch_size=5, epochs=30,
    callbacks=[my_test_callback],
    validation_data=(Xval, Yval))
# Out:
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7305 - loss: 0.7914 - val_accuracy: 0.7960 - val_loss: 0.5829
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8135 - loss: 0.5445 - val_accuracy: 0.8155 - val_loss: 0.5161
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8327 - loss: 0.4858 - val_accuracy: 0.8240 - val_loss: 0.4834
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8449 - loss: 0.4499 - val_accuracy: 0.8355 - val_loss: 0.4640
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8521 - loss: 0.4231 - val_accuracy: 0.8425 - val_loss: 0.4504
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8594 - loss: 0.4015 - val_accuracy: 0.8465 - val_loss: 0.4355
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8670 - loss: 0.3831 - val_accuracy: 0.8490 - val_loss: 0.4297
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8735 - loss: 0.3675 - val_accuracy: 0.8520 - val_loss: 0.4247
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8781 - loss: 0.3531 - val_accuracy: 0.8560 - val_loss: 0.4151
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8844 - loss: 0.3403 - val_accuracy: 0.8530 - val_loss: 0.4188
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8887 - loss: 0.3282 - val_accuracy: 0.8570 - val_loss: 0.4077
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8920 - loss: 0.3170 - val_accuracy: 0.8570 - val_loss: 0.4046
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8931 - loss: 0.3073 - val_accuracy: 0.8580 - val_loss: 0.4101
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8978 - loss: 0.2973 - val_accuracy: 0.8605 - val_loss: 0.4039
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8999 - loss: 0.2880 - val_accuracy: 0.8570 - val_loss: 0.4034
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9026 - loss: 0.2789 - val_accuracy: 0.8575 - val_loss: 0.3960
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9061 - loss: 0.2703 - val_accuracy: 0.8580 - val_loss: 0.3946
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9100 - loss: 0.2624 - val_accuracy: 0.8555 - val_loss: 0.4011
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9119 - loss: 0.2544 - val_accuracy: 0.8595 - val_loss: 0.3951
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9156 - loss: 0.2467 - val_accuracy: 0.8585 - val_loss: 0.3977
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9184 - loss: 0.2394 - val_accuracy: 0.8590 - val_loss: 0.4016
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9214 - loss: 0.2318 - val_accuracy: 0.8595 - val_loss: 0.4010
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9243 - loss: 0.2258 - val_accuracy: 0.8565 - val_loss: 0.3971
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9251 - loss: 0.2197 - val_accuracy: 0.8595 - val_loss: 0.4031
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9286 - loss: 0.2132 - val_accuracy: 0.8590 - val_loss: 0.4024
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9316 - loss: 0.2070 - val_accuracy: 0.8615 - val_loss: 0.4043
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9335 - loss: 0.2015 - val_accuracy: 0.8615 - val_loss: 0.4062
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9361 - loss: 0.1951 - val_accuracy: 0.8580 - val_loss: 0.4140
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9370 - loss: 0.1904 - val_accuracy: 0.8600 - val_loss: 0.4089
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9414 - loss: 0.1838 - val_accuracy: 0.8595 - val_loss: 0.4111

# %% [markdown]
# ### Visualize the accuracy without early-stopping
#
# Run the provided code to plot the training accuracy *vs.* the number of epochs. On the same graph, we plot the test accuracy *vs.* the number of epochs. To do this, we retrieve loss and accuracy information in `train_test_history.history`. We also use `plt.scatter` to mark the point on the test accuracy curve where we early-stopped previously.

# %%
x = np.arange(len(train_test_history.history['accuracy']))
train_acc = train_test_history.history['accuracy']
val_acc = train_test_history.history['val_accuracy']

plt.title("Train-val-test accuracy through the epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(x, train_acc, label="train acc")
plt.plot(x, val_acc, label="val acc")
plt.plot(x, test_acc, label="test acc")
plt.scatter([x[12]], [val_acc[12]], color="red")
plt.legend()
plt.show()

# %% [markdown]
# Based on the curve, answer the following questions:
#
# *   What is the trend of training and test accuracy after the early-stopped point?
# *   Based on the plot, what do you think could go wrong if the patience parameter for early-stopping is too small?

# %% [markdown]
# ## Problem 3.4: SGD with momentum

# %% [markdown]
# We mentioned in the lecture that adding a “momentum” term, which encourages model to continue along previous gradient direction, helps the network to converge. Concretely, with an initial velocity $v=0$, we update the gradient by
#
# $v ← \alpha v + \nabla F(w)$
#
# $w ← w - \eta v$
#
# where $\eta$ is the learning rate and $\alpha$ is the factor describing how much weight we put on the previous gradients. $\alpha=0$ is equivalent to gradient update without momentum.
#
# We provide the `sgd_with_momentum` function with argument $\alpha$ below. In this question, we will explore the  momentum factor $\alpha$ effects training loss and test accuracy.

# %%
def sgd_with_momentum(alpha):
  # set the same random seed to make sure the model initialized at the same weights.
  tf.random.set_seed(42)
  tf.compat.v1.set_random_seed(42)
  tf.experimental.numpy.random.seed(42)
  # build the model
  model = tf.keras.Sequential([
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(10)
  ])
  # compile the model
  model.compile(optimizer=tf.keras.optimizers.SGD(momentum=alpha),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  # train the model without early-stopping
  history = model.fit(
      Xtrain, Ytrain,
      batch_size=5, epochs=30)
  # evaluate the model
  test_loss, test_acc = model.evaluate(Xtest,  Ytest, verbose=2)
  # return training loss and test accuracy
  return history.history['loss']

# %% [markdown]
# ### Visualize training loss and test accuracy with different momentum factor $\alpha$
#
# We will explore how different momentum factor $\alpha$ effects training loss and test accuracy. Call the `sgd_with_momentum` function with $\alpha$ = 0.1, 0.3, 0.5, 0.7, 0.9. Store the training loss and test accuracy from the return of the function.

# %%
train_losses = []

for alpha in np.arange(0.1, 1, 0.2):
  train_loss = sgd_with_momentum(alpha)
  train_losses.append(train_loss)
# Out:
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7418 - loss: 0.7763
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8162 - loss: 0.5416
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8333 - loss: 0.4838
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8468 - loss: 0.4471
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8564 - loss: 0.4199
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8632 - loss: 0.3977
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8711 - loss: 0.3791
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8762 - loss: 0.3628
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8816 - loss: 0.3478
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8872 - loss: 0.3344
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8915 - loss: 0.3216
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8945 - loss: 0.3099
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8993 - loss: 0.2984
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9034 - loss: 0.2880
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9054 - loss: 0.2776
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9081 - loss: 0.2690
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9113 - loss: 0.2598
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9155 - loss: 0.2508
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9194 - loss: 0.2424
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9217 - loss: 0.2343
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9247 - loss: 0.2271
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9276 - loss: 0.2203
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9302 - loss: 0.2133
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9321 - loss: 0.2066
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9339 - loss: 0.2004
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9372 - loss: 0.1945
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9399 - loss: 0.1878
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9416 - loss: 0.1820
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9444 - loss: 0.1758
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9462 - loss: 0.1708
# 313/313 - 1s - 2ms/step - accuracy: 0.8501 - loss: 0.4741
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7476 - loss: 0.7509
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8188 - loss: 0.5245
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8380 - loss: 0.4664
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8503 - loss: 0.4302
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8616 - loss: 0.4027
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8676 - loss: 0.3807
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8749 - loss: 0.3608
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8812 - loss: 0.3438
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8857 - loss: 0.3295
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8907 - loss: 0.3154
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8965 - loss: 0.3016
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9000 - loss: 0.2897
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9052 - loss: 0.2770
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9082 - loss: 0.2669
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9119 - loss: 0.2568
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9154 - loss: 0.2470
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9206 - loss: 0.2378
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9221 - loss: 0.2293
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9243 - loss: 0.2208
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9280 - loss: 0.2125
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9315 - loss: 0.2056
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9326 - loss: 0.1979
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9356 - loss: 0.1915
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9375 - loss: 0.1850
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9401 - loss: 0.1783
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9436 - loss: 0.1716
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9455 - loss: 0.1661
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9486 - loss: 0.1594
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9503 - loss: 0.1537
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9539 - loss: 0.1482
# 313/313 - 1s - 3ms/step - accuracy: 0.8499 - loss: 0.4939
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7505 - loss: 0.7192
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8238 - loss: 0.5064
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8401 - loss: 0.4474
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8551 - loss: 0.4093
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8642 - loss: 0.3813
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8722 - loss: 0.3587
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8800 - loss: 0.3387
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8867 - loss: 0.3202
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8923 - loss: 0.3052
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8992 - loss: 0.2894
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9034 - loss: 0.2762
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9076 - loss: 0.2640
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9112 - loss: 0.2527
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9140 - loss: 0.2417
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9174 - loss: 0.2319
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9231 - loss: 0.2212
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9242 - loss: 0.2136
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9301 - loss: 0.2028
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9332 - loss: 0.1949
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9350 - loss: 0.1891
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9383 - loss: 0.1810
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9423 - loss: 0.1725
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9467 - loss: 0.1633
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9485 - loss: 0.1582
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9514 - loss: 0.1508
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9517 - loss: 0.1460
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9538 - loss: 0.1379
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9574 - loss: 0.1309
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9597 - loss: 0.1264
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9613 - loss: 0.1214
# 313/313 - 1s - 2ms/step - accuracy: 0.8489 - loss: 0.5370
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7541 - loss: 0.6936
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8251 - loss: 0.4966
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8435 - loss: 0.4376
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8564 - loss: 0.3970
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8666 - loss: 0.3674
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8760 - loss: 0.3446
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8842 - loss: 0.3228
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8893 - loss: 0.3049
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8948 - loss: 0.2911
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9025 - loss: 0.2754
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9070 - loss: 0.2621
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9099 - loss: 0.2508
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9154 - loss: 0.2375
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9182 - loss: 0.2268
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9237 - loss: 0.2179
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9296 - loss: 0.2062
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9284 - loss: 0.1979
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9330 - loss: 0.1913
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9368 - loss: 0.1834
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9405 - loss: 0.1754
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9418 - loss: 0.1677
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9473 - loss: 0.1582
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9470 - loss: 0.1549
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9507 - loss: 0.1481
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9512 - loss: 0.1417
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9553 - loss: 0.1367
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9574 - loss: 0.1286
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9591 - loss: 0.1236
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9586 - loss: 0.1202
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9602 - loss: 0.1157
# 313/313 - 1s - 2ms/step - accuracy: 0.8448 - loss: 0.6114
# Epoch 1/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7352 - loss: 0.7443
# Epoch 2/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7956 - loss: 0.5734
# Epoch 3/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8198 - loss: 0.5033
# Epoch 4/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8362 - loss: 0.4617
# Epoch 5/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8414 - loss: 0.4402
# Epoch 6/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8484 - loss: 0.4142
# Epoch 7/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8535 - loss: 0.4093
# Epoch 8/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8601 - loss: 0.3872
# Epoch 9/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8642 - loss: 0.3716
# Epoch 10/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8688 - loss: 0.3589
# Epoch 11/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8749 - loss: 0.3402
# Epoch 12/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8827 - loss: 0.3260
# Epoch 13/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8821 - loss: 0.3214
# Epoch 14/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8890 - loss: 0.3052
# Epoch 15/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8932 - loss: 0.2921
# Epoch 16/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8884 - loss: 0.3081
# Epoch 17/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8953 - loss: 0.2824
# Epoch 18/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8948 - loss: 0.2886
# Epoch 19/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8938 - loss: 0.2857
# Epoch 20/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8944 - loss: 0.2879
# Epoch 21/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8998 - loss: 0.2733
# Epoch 22/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9032 - loss: 0.2592
# Epoch 23/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9086 - loss: 0.2454
# Epoch 24/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9099 - loss: 0.2425
# Epoch 25/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9077 - loss: 0.2561
# Epoch 26/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9126 - loss: 0.2383
# Epoch 27/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9136 - loss: 0.2328
# Epoch 28/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9163 - loss: 0.2247
# Epoch 29/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9181 - loss: 0.2154
# Epoch 30/30
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9195 - loss: 0.2143
# 313/313 - 1s - 2ms/step - accuracy: 0.8277 - loss: 0.7691

# %% [markdown]
# We visualize the training loss. Plot 5 curve of different $\alpha$ on the same graph. Each curve has epoch number as the $x$-axis and the training loss as the $y$-axis.  Based on this, what is a suitable value of $\alpha$? Therefore, how should training ideally rely on previous gradients for better convergence?

# %%
x = np.arange(len(train_losses[0]))

plt.title("Training loss through the epochs for different SGD momentum")
plt.xlabel("Epoch")
plt.ylabel("Loss")
for i, alpha in enumerate(np.arange(0.1, 1, 0.2)):
  plt.plot(x, train_losses[i], label="momentum=%f" % alpha)
plt.legend()
plt.show()

# %% [markdown]
# ## [Bonus] Problem 3.5: Out-of-domain generalization

# %% [markdown]
# A major research direction at present is to ensure that our ML models not only do well on test data drawn from the same distribution as training data, but also do well when they get data from distributions different from the original distribution. This is known as Out-of-Distribution (OOD) generalization. In the Fashion MNIST dataset, the training and test set are drawn from the same distribution. Let's explore how our models do on test data coming from a slightly different distribution.

# %% [markdown]
# ### Create OOD test set by translation
#
# Take a look at the original test set of Fashion MNIST.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(Xtest[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(class_names[Ytest[i]])
plt.show()

# %% [markdown]
# We move up the images of the test set by 4 pixels, and create a new translated test set from that. You will notice that to a human eye, the new test set is not any more difficult than the original test set.

# %%
# lift the image by 4 pixels
translate_x = 4
translate_y = 0

Xtest_t4 = np.pad(Xtest.reshape(-1, 28, 28)[:, translate_x:, translate_y:],
                  ((0, 0), (0, translate_x), (0, translate_y))).reshape(-1, 784)


# visualize the translation
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(Xtest_t4[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(class_names[Ytest[i]])
plt.show()

# %% [markdown]
# *But can the MLP model still identify it well?* Check the test accuracy on the base model.

# %%
test_loss, test_acc = base_model.evaluate(Xtest_t4,  Ytest, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.4550 - loss: 2.2849
#
# Test accuracy: 0.45500001311302185

# %% [markdown]
# ### Convolutional Neural Network
#
# What if we try a different model architecture? For example, in class we saw that convolutional neural networks are good at dealing with image translation. We replace the first linear layer with a convolutional layer of 64 kernels with size $7\times7$, followed by max-pooling. This can be done with just one or two lines of code in TensorFlow. We train the 2-layer CNN on the original training data and test it on both the original and the translated test sets.

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_accuracy",
        # "no longer improving" being defined as "for at least 3 epochs"
        patience=3,
        verbose=1,
    )
]
# set the same random seed.
tf.random.set_seed(42)
tf.compat.v1.set_random_seed(42)
tf.experimental.numpy.random.seed(42)
# replace the linear layer with a conv layer of 64 7*7 kernels, followed by maxpooling.
cnn_model = tf.keras.Sequential([
    tf.keras.layers.Reshape((28, 28, 1), input_shape=(784,)),
    tf.keras.layers.Conv2D(64, (7, 7), activation='relu'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10)
])
# compile the model
cnn_model.compile(optimizer='sgd',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# train the model with early-stopping
cnn_model.fit(
    Xtrain, Ytrain,
    batch_size=5, epochs=50,
    callbacks=callbacks,
    validation_data=(Xval, Yval))
# evaluate on the original test set
test_loss, test_acc = cnn_model.evaluate(Xtest,  Ytest, verbose=2)
print('In-domain test accuracy:', test_acc)
# evaluate on the translated test set
test_loss, test_acc = cnn_model.evaluate(Xtest_t4,  Ytest, verbose=2)
print('Out-of-domain test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7247 - loss: 0.7891 - val_accuracy: 0.8035 - val_loss: 0.5459
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8225 - loss: 0.5151 - val_accuracy: 0.8295 - val_loss: 0.4696
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8425 - loss: 0.4523 - val_accuracy: 0.8435 - val_loss: 0.4343
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8584 - loss: 0.4142 - val_accuracy: 0.8545 - val_loss: 0.4119
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8663 - loss: 0.3857 - val_accuracy: 0.8605 - val_loss: 0.3959
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8742 - loss: 0.3626 - val_accuracy: 0.8660 - val_loss: 0.3833
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8796 - loss: 0.3433 - val_accuracy: 0.8705 - val_loss: 0.3738
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8848 - loss: 0.3266 - val_accuracy: 0.8730 - val_loss: 0.3662
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8910 - loss: 0.3118 - val_accuracy: 0.8760 - val_loss: 0.3603
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8956 - loss: 0.2983 - val_accuracy: 0.8775 - val_loss: 0.3549
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8989 - loss: 0.2857 - val_accuracy: 0.8800 - val_loss: 0.3510
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9039 - loss: 0.2742 - val_accuracy: 0.8810 - val_loss: 0.3479
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9074 - loss: 0.2633 - val_accuracy: 0.8810 - val_loss: 0.3446
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9117 - loss: 0.2530 - val_accuracy: 0.8800 - val_loss: 0.3429
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9150 - loss: 0.2433 - val_accuracy: 0.8820 - val_loss: 0.3420
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9185 - loss: 0.2340 - val_accuracy: 0.8855 - val_loss: 0.3418
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9208 - loss: 0.2252 - val_accuracy: 0.8830 - val_loss: 0.3413
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9245 - loss: 0.2168 - val_accuracy: 0.8835 - val_loss: 0.3403
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9269 - loss: 0.2088 - val_accuracy: 0.8860 - val_loss: 0.3410
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9302 - loss: 0.2008 - val_accuracy: 0.8855 - val_loss: 0.3409
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9331 - loss: 0.1934 - val_accuracy: 0.8850 - val_loss: 0.3419
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9355 - loss: 0.1861 - val_accuracy: 0.8860 - val_loss: 0.3429
# Epoch 22: early stopping
# 313/313 - 2s - 6ms/step - accuracy: 0.8756 - loss: 0.3799
# In-domain test accuracy: 0.8755999803543091
# 313/313 - 3s - 8ms/step - accuracy: 0.5049 - loss: 2.0872
# Out-of-domain test accuracy: 0.5048999786376953

# %% [markdown]
# Show the CNN model has fewer parameters (compute by hand, you can use
# `cnn_model.trainable_variables` to verify your calculation) than the 2-layer
# MLP. What is the in-domain test accuracy and the translated test accuracy?

# %% [markdown]
# ### Make the CNN Deeper
#
# Going one step further, we can make the CNN deeper by adding one more convolutional layer between the two existing layers.

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_accuracy",
        # "no longer improving" being defined as "for at least 3 epochs"
        patience=3,
        verbose=1,
    )
]
# set the same random seed.
tf.random.set_seed(42)
tf.compat.v1.set_random_seed(42)
tf.experimental.numpy.random.seed(42)
# add one more conv layer of 128 2*2 kernels in between, followed by maxpooling.
cnn_model_deeper = tf.keras.Sequential([
    tf.keras.layers.Reshape((28, 28, 1), input_shape=(784,)),
    tf.keras.layers.Conv2D(64, (7, 7), activation='relu'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Conv2D(128, (2, 2), activation='relu'),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10)
])
# compile the model
cnn_model_deeper.compile(optimizer='sgd',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# train the model with early-stopping
cnn_model_deeper.fit(
    Xtrain, Ytrain,
    batch_size=5, epochs=50,
    callbacks=callbacks,
    validation_data=(Xval, Yval))
# evaluate on the original test set
test_loss, test_acc = cnn_model_deeper.evaluate(Xtest,  Ytest, verbose=2)
print('In-domain test accuracy:', test_acc)
# evaluate on the translated test set
test_loss, test_acc = cnn_model_deeper.evaluate(Xtest_t4,  Ytest, verbose=2)
print('Out-of-domain test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.6620 - loss: 0.9401 - val_accuracy: 0.7775 - val_loss: 0.6115
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8001 - loss: 0.5666 - val_accuracy: 0.8165 - val_loss: 0.5141
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8315 - loss: 0.4860 - val_accuracy: 0.8335 - val_loss: 0.4723
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8473 - loss: 0.4406 - val_accuracy: 0.8395 - val_loss: 0.4462
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8572 - loss: 0.4092 - val_accuracy: 0.8470 - val_loss: 0.4286
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8652 - loss: 0.3852 - val_accuracy: 0.8510 - val_loss: 0.4144
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8720 - loss: 0.3649 - val_accuracy: 0.8555 - val_loss: 0.4012
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8782 - loss: 0.3474 - val_accuracy: 0.8570 - val_loss: 0.3916
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8836 - loss: 0.3320 - val_accuracy: 0.8605 - val_loss: 0.3831
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8890 - loss: 0.3179 - val_accuracy: 0.8640 - val_loss: 0.3780
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.8926 - loss: 0.3048 - val_accuracy: 0.8665 - val_loss: 0.3740
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8964 - loss: 0.2928 - val_accuracy: 0.8690 - val_loss: 0.3711
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.9005 - loss: 0.2815 - val_accuracy: 0.8715 - val_loss: 0.3687
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9041 - loss: 0.2707 - val_accuracy: 0.8710 - val_loss: 0.3668
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.9098 - loss: 0.2602 - val_accuracy: 0.8735 - val_loss: 0.3666
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9131 - loss: 0.2502 - val_accuracy: 0.8745 - val_loss: 0.3641
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9155 - loss: 0.2402 - val_accuracy: 0.8745 - val_loss: 0.3673
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.9187 - loss: 0.2305 - val_accuracy: 0.8760 - val_loss: 0.3696
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.9235 - loss: 0.2212 - val_accuracy: 0.8725 - val_loss: 0.3723
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9267 - loss: 0.2121 - val_accuracy: 0.8745 - val_loss: 0.3754
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9299 - loss: 0.2030 - val_accuracy: 0.8740 - val_loss: 0.3748
# Epoch 21: early stopping
# 313/313 - 4s - 14ms/step - accuracy: 0.8739 - loss: 0.3997
# In-domain test accuracy: 0.8738999962806702
# 313/313 - 3s - 9ms/step - accuracy: 0.5190 - loss: 1.8420
# Out-of-domain test accuracy: 0.5189999938011169

# %% [markdown]
# Show the deeper 3-layer CNN model has fewer parameters (compute by hand, you can use `cnn_model.trainable_variables` to verify your calculation) than the 2-layer CNN model. What is the in-domain and the translated test accuracy of the deeper CNN model? Provide some intuition on why it is better than the 2-layer CNN on the translated set.

# %% [markdown]
# ### Create OOD test set by rotation

# %% [markdown]
# Next, we create 3 more OOD test sets by rotation. We rotate the images in the original test set by 90, 180 and 270 degrees.

# %%
# rotate 90 degrees counter-clockwise
Xtest_r90 = np.rot90(Xtest.reshape(-1, 28, 28), k=1, axes=(1, 2)).reshape(-1, 784)

# rotate 180 degrees counter-clockwise
Xtest_r180 = np.rot90(Xtest.reshape(-1, 28, 28), k=2, axes=(1, 2)).reshape(-1, 784)

# rotate 270 degrees counter-clockwise
Xtest_r270 = np.rot90(Xtest.reshape(-1, 28, 28), k=3, axes=(1, 2)).reshape(-1, 784)

# visualize the 90 degrees rotation
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(Xtest_r90[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.xlabel(class_names[Ytest[i]])
plt.show()

# %% [markdown]
# Provide the test accuracy of the base model, the CNN model  and the deeper CNN model on the three rotation test sets. Are the CNN and the deeper CNN still doing well?

# %%
print("Rotation 90 degrees:")

test_loss, test_acc = base_model.evaluate(Xtest_r90,  Ytest, verbose=2)
print('Base model accuracy:', test_acc)
test_loss, test_acc = cnn_model.evaluate(Xtest_r90,  Ytest, verbose=2)
print('CNN model accuracy:', test_acc)
test_loss, test_acc = cnn_model_deeper.evaluate(Xtest_r90,  Ytest, verbose=2)
print('Deeper CNN model accuracy:', test_acc)

print("Rotation 180 degrees:")

test_loss, test_acc = base_model.evaluate(Xtest_r180,  Ytest, verbose=2)
print('Base model accuracy:', test_acc)
test_loss, test_acc = cnn_model.evaluate(Xtest_r180,  Ytest, verbose=2)
print('CNN model accuracy:', test_acc)
test_loss, test_acc = cnn_model_deeper.evaluate(Xtest_r270,  Ytest, verbose=2)
print('Deeper CNN model accuracy:', test_acc)

print("Rotation 270 degrees:")

test_loss, test_acc = base_model.evaluate(Xtest_r270,  Ytest, verbose=2)
print('Base model accuracy:', test_acc)
test_loss, test_acc = cnn_model.evaluate(Xtest_r270,  Ytest, verbose=2)
print('CNN model accuracy:', test_acc)
test_loss, test_acc = cnn_model_deeper.evaluate(Xtest_r270,  Ytest, verbose=2)
print('Deeper CNN model accuracy:', test_acc)
# Out:
# Rotation 90 degrees:
# 313/313 - 1s - 2ms/step - accuracy: 0.0280 - loss: 7.6407
# Base model accuracy: 0.02800000086426735
# 313/313 - 2s - 6ms/step - accuracy: 0.0637 - loss: 7.5195
# CNN model accuracy: 0.06369999796152115
# 313/313 - 3s - 9ms/step - accuracy: 0.0450 - loss: 7.5205
# Deeper CNN model accuracy: 0.04500000178813934
# Rotation 180 degrees:
# 313/313 - 1s - 2ms/step - accuracy: 0.1630 - loss: 5.2823
# Base model accuracy: 0.16300000250339508
# 313/313 - 2s - 6ms/step - accuracy: 0.1987 - loss: 5.4723
# CNN model accuracy: 0.19869999587535858
# 313/313 - 4s - 13ms/step - accuracy: 0.0467 - loss: 9.6598
# Deeper CNN model accuracy: 0.04670000076293945
# Rotation 270 degrees:
# 313/313 - 1s - 2ms/step - accuracy: 0.0484 - loss: 10.2160
# Base model accuracy: 0.04839999973773956
# 313/313 - 2s - 6ms/step - accuracy: 0.0425 - loss: 10.0662
# CNN model accuracy: 0.042500000447034836
# 313/313 - 3s - 9ms/step - accuracy: 0.0467 - loss: 9.6598
# Deeper CNN model accuracy: 0.04670000076293945
